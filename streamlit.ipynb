# %%
# !pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.1 MB 1.0 MB/s eta 0:00:10
#    --- ------------------------------------ 0.8/10.1 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/10.1 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/10.1 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/10.1 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/10.1 MB 1.1 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/10.1 MB 1.1 MB/s eta 0:00:08
#    -------- ------------------------------- 2.1/10.1 MB 1.1 MB/s eta 0:00:08
#    --------- ------------------------------ 2.4/10.1 MB 1.1 MB/s eta 0:00:07
# ...

# %%
import streamlit as st
st.title("Hello world!")

# streamlit run streamlit.py
# Out:
# 2025-11-03 11:12:16.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 11:12:16.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 11:12:16.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
